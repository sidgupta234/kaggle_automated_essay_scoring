# %%
import numpy as np, pandas as pd, sklearn, matplotlib.pyplot as plt, seaborn as sns

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from transformers import AutoTokenizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [93], in <cell line: 2>()
#       1 from nltk.tokenize import word_tokenize, sent_tokenize
# ----> 2 from transformers import AutoTokenizer
#
# ModuleNotFoundError: No module named 'transformers'

# %%
dataset = pd.read_csv('data/train.csv')

# %%
dataset.shape
# Out:
# (3911, 8)

# %%
dataset.columns
# Out:
# Index(['text_id', 'full_text', 'cohesion', 'syntax', 'vocabulary',
#        'phraseology', 'grammar', 'conventions'],
#       dtype='object')

# %%
dataset.head(1)
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0

# %%
essays = dataset.full_text.to_list()
all_words = " ".join(essays)

# %%
len(all_words)
# Out:
# 9134227

# %%
fig, axs = plt.subplots(ncols=3, nrows = 2)
sns.set(rc={'figure.figsize':(16,12)})
for iter_, i in enumerate(dataset.columns):
    if i not in ['text_id', 'full_text']:
        row = iter_//3
        col = iter_%3
        print(row, col)
        sns.countplot(x = dataset[i], data = dataset, ax=axs[row-1][col])#, normalize=True)
# Out:
# 0 2
# 1 0
# 1 1
# 1 2
# 2 0
# 2 1

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v3-large")
dataset['text_length'] = dataset['full_text'].apply(lambda x: len(x.split()))
dataset['tokens_length'] = dataset['full_text'].apply(lambda x: len(tokenizer(x, add_special_tokens=True)['input_ids']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 tokenizer = AutoTokenizer.from_pretrained("microsoft/deberta-v3-large")
#       2 dataset['text_length'] = dataset['full_text'].apply(lambda x: len(x.split()))
#       3 dataset['tokens_length'] = dataset['full_text'].apply(lambda x: len(tokenizer(x, add_special_tokens=True)['input_ids']))
#
# NameError: name 'AutoTokenizer' is not defined

# %%
# Out:
# 1683658
